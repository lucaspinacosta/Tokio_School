# %% [markdown]
# # Exercícios Módulo 4. Unidade 1. Outras ferramentas de POO (Soluções)
#
# Considerações a ter em conta:
#
# - Guardar este documento com o seguinte formato para entrega: __M4_01_nome_apelido1_apelido2__
# - Fazer os exercícios com as ferramentas vistas nas sessões.
# - Comentar o código
# - Utilizar nomes de variáveis apropriados, se vai guardar uma nota, chamar a essa variável nota, não n ou x

# %% [markdown]
# **1) Exercício de herança múltipla e polimorfismo**
# * Criar a classe Veículos com um construtor que inclua marca e modelo
# * Esta classe Veículos também terá de incluir um método que se chame reabastecer() o qual imprime por ecrã “Este veículo tem de reabastecer gasolina”
# * Criar a classe VElétricos com um construtor que inclua marca, modelo e autonomia
# * Esta classe VElétricos também terá de incluir um método que se chame repostar() o qual imprime por ecrã “Este veículo tem de reabastecer eletricidade”
# * Criar a classe BicicletaElétrica que herde de Veículos e de VElétricos, mas dando prioridade a VElétricos (já que é um veículo mais elétrico que normal)
# * Criar a classe Quad que herde de Veículos e de VElétricos, mas dando prioridade a Veículos (já que apenas usa a eletricidade de modo pontual)
# * Criar um objeto de BicicletaElétrica e outro de Quad
# * Empregar as técnicas de polimorfismo aprendidas para conseguir que ao perguntar-lhe aos objetos que acabamos de criar por reabastecimento, ambos nos respondam adequadamente

# %%
# Completar o exercício aqui

class Veiculo():
    def __init__(self,modelo,marca):
        self.modelo = modelo
        self.marca = marca

    def abastecer(self):
        return 'Este veiculo tem de reabastecer gasolina!'

    def __str__(self):
        print('Classe Veiculo!')

class VEletricos():
    def __init__(self,modelo, marca):
        self.modelo = modelo
        self.marca = marca
        self.autonomia = 100

    def repostar(self):
        return 'Este veiculo tem de reabastecer eletricidade!'

    def __str__(self):
        print('Veiculo Eletrico.')

class BicicletaEletrica(VEletricos,Veiculo):
    pass
    
class Quad(Veiculo,VEletricos):
    pass

minhaBike = BicicletaEletrica('cross','ktm')
meuQuad = Quad('cross','Ktm')

print(minhaBike.repostar())
print(meuQuad.abastecer())
# Out:
# Este veiculo tem de reabastecer eletricidade!
# Este veiculo tem de reabastecer gasolina!

# %% [markdown]
# **2) Exercício de herança**
# * Criar a superclasse Pessoal_Universitário com um único atributo que seja um dicionário que inclua: “id”, “nome” e “email”
# * Criar as classes Oficina, Professor e Aluno. Todas herdaram de Pessoal_Universitário e os seus dados
# * No caso de Oficina, deve adicionar ao seu dicionário de dados o dado “Posto”
# * No caso de Professor, deve adicionar ao seu dicionário de dados o dado “Especialização”
# * No caso de Aluno, deve adicionar ao seu dicionário de dados o dado “CréditosAprovados" (integer)
# * Criar métodos que sirvam para mostrar a informação de cada classe
# * Criar objetos de todas as classes
# * Mostrar a informação desses objetos e comprovar que sai o que tem de sair

# %%
# Completar o exercício aqui
class Pessoal_Universitario():
    #Criar a superclasse Pessoal_Universitário com um único atributo que seja um 
    #dicionário que inclua: “id”, “nome” e “email”
    dic = {}
    def __init__(self,ID,nome,email):
        self.dic['ID']=ID
        self.dic['nome'] = nome
        self.dic['email'] = email

    def __str__(self):
        return f"Nome: {self.dic['nome']} || ID: {self.dic['ID']} || Email: {self.dic['email']}"

#Criar as classes Oficina, Professor e Aluno. Todas herdaram de 
#Pessoal_Universitário e os seus dados
class Oficina(Pessoal_Universitario):
    def __init__(self,ID,nome,email,posto):
        super().__init__(ID,nome,email)
        self.dic['posto'] = posto

    def __str__(self):
        return f"Nome: {self.dic['nome']} || ID: {self.dic['ID']} || Email: {self.dic['email']} || Posto: {self.dic['posto']}"

class Professor(Pessoal_Universitario):
    def __init__(self,ID,nome,email,especializacao):
        super().__init__(ID,nome,email)
        self.dic['especializacao'] = especializacao
    
    def __str__(self):
        return f"Nome: {self.dic['nome']} || ID: {self.dic['ID']} || Email: {self.dic['email']} || Especializacao: {self.dic['especializacao']}"

class Aluno(Pessoal_Universitario):
    def __init__(self,ID,nome,email,creditosAprovados):
        super().__init__(ID,nome,email)
        self.dic['creditosAprovados'] = int(creditosAprovados)

    def __str__(self):
        return f"Nome: {self.dic['nome']} || ID: {self.dic['ID']} || Email: {self.dic['email']} || Ceditos: {self.dic['creditosAprovados']}"


pessoalUniver1 = Pessoal_Universitario('34252343','Araujo','araujo_araujo@gmail.com')
print(pessoalUniver1)

oficina1 = Oficina('3242423','Ricardo','ricardo_ricky@gmail.com','funcionario')
print(oficina1)

professor1 = Professor('23452345','Irene','dona_irene@gmail.com','Ingles')
print(professor1)

aluno1 = Aluno('6487456','Julio','julioRocha@gmail.com',20)
print(aluno1)
# Out:
# Nome: Araujo || ID: 34252343 || Email: araujo_araujo@gmail.com
# Nome: Ricardo || ID: 3242423 || Email: ricardo_ricky@gmail.com || Posto: funcionario
# Nome: Irene || ID: 23452345 || Email: dona_irene@gmail.com || Especializacao: Ingles
# Nome: Julio || ID: 6487456 || Email: julioRocha@gmail.com || Ceditos: 20

# %% [markdown]
# **3)  Escolher a temática que preferir e definir uma estrutura de classes e subclasses onde pratique a herança em pelo menos dois níveis (herança multinível). Criar uma estrutura de mínimo 5 classes, com os seus respetivos construtores e métodos. Criar alguns objetos e comprovar que a herança esteja a funcionar. Se puder incluir alguma técnica de polimorfismo.**

# %%
from datetime import datetime,timedelta
import pytz

class App():
    def __init__(self,nome,duracao, produtor):
        self.nome = nome
        self.duracao = str(duracao)
        self.produtor = produtor

    def __str__(self):
        return None

class Filmes(App):
    def __init__(self,nome,duracao, produtor):
        super().__init__(nome,duracao,produtor)

    def duracao_seccao(self):
        current_utc = datetime.utcnow().replace(tzinfo= pytz.utc)
        lisbon_tz = pytz.timezone("Europe/Lisbon")
        lisbon_now = current_utc.astimezone(lisbon_tz)
        tempo_filme = self.duracao
        try:
            horas, minutos,segundos = map(int, tempo_filme.split(':'))
            tempo_filme = timedelta (hours=horas,minutes=minutos,seconds=segundos)
            duracao_seccao = lisbon_now + tempo_filme
            return f"Fim da seccao as {duracao_seccao.hour}:{duracao_seccao.minute}H"
        except: return "Duracao da seccao indisponivel."
    
    def comprar_Bilhete(Genero):
        bilhete = False
        valor_bilhetes = {'Accao': 5,'Aventura':5,'Si-Fi':5, "Infantil":3.5}
        for genero,valor in valor_bilhetes:
            if genero == Genero:
                print(valor)
                bilhete = True
            else:print("Erro na compra do bilhete")
        
    def __str__(self):
        return "Escolha um filme"

class Accao(Filmes):
    def __init__(self,nome,duracao,produtor):
        super().__init__(nome,duracao,produtor)
        self.genero = "Accao"

    def informacao(self):
        self.descricao = {'Nome':self.nome,'Genero':self.genero,'Produtora':self.produtor}
        print (f"\nFilme: {self.descricao['Nome']}\nGenero: {self.descricao['Genero']}\nProdutora: {self.descricao['Produtora']}\n{self.duracao_seccao()}\nValor do bilhete: {valor_bilhetes(self.descricao['Genero'])}€")

    def comprar_bilhete(self):
        disponiveis = 100
        preco = valor_bilhetes(self.genero)
        quantidade_a_comprar =int(input('Quantos bilhetes pretende comprar?'))
        disponiveis -= quantidade_a_comprar
        valor_a_pagar = float(quantidade_a_comprar) *float(preco)
        print(f'Restam {disponiveis} bilhetes')
        print( f"Bilhetes:{quantidade_a_comprar}\nValor a pagar:{valor_a_pagar}€")
        
    def __str__(self):
        return f'\nFilme: {self.nome}\nGenero: {self.genero}\nTempo de Filme: {self.duracao[0]}:{self.duracao[2:]}'

class Aventura(Filmes):
    def __init__(self,nome,duracao,produtor):
        super().__init__(nome,duracao,produtor)
        self.genero = "Aventura"
    
    def informacao(self):
        self.descricao = {'Nome':self.nome,'Genero':self.genero,'Produtora':self.produtor}
        print (f"\nFilme: {self.descricao['Nome']}\nGenero: {self.descricao['Genero']}\nProdutora: {self.descricao['Produtora']}\n{self.duracao_seccao()}\nValor do bilhete: {valor_bilhetes(self.descricao['Genero'])}€")

    def comprar_bilhete(self):
        disponiveis = 100
        preco = valor_bilhetes(self.genero)
        quantidade_a_comprar =int(input('Quantos bilhetes pretende comprar?'))
        disponiveis -= quantidade_a_comprar
        valor_a_pagar = float(quantidade_a_comprar) *float(preco)
        print(f'\nRestam {disponiveis} bilhetes')
        print( f"Bilhetes:{quantidade_a_comprar}\nValor a pagar:{valor_a_pagar}€")

    def __str__(self):
        return f'\nFilme: {self.nome}\nGenero: {self.genero}\nTempo de Filme: {self.duracao[0]}:{self.duracao[2:]}'

class Si_Fi(Filmes):
    def __init__(self,nome,duracao,produtor):
        super().__init__(nome,duracao,produtor)
        self.genero = "Si-Fi"

    def informacao(self):
        self.descricao = {'Nome':self.nome,'Genero':self.genero,'Produtora':self.produtor}
        print (f"\nFilme: {self.descricao['Nome']}\nGenero: {self.descricao['Genero']}\nProdutora: {self.descricao['Produtora']}\n{self.duracao_seccao()}\nValor do bilhete: {valor_bilhetes(self.descricao['Genero'])}€")

    def comprar_bilhete(self):
        disponiveis = 100
        preco = valor_bilhetes(self.genero)
        quantidade_a_comprar =int(input('Quantos bilhetes pretende comprar?'))
        disponiveis -= quantidade_a_comprar
        valor_a_pagar = float(quantidade_a_comprar) *float(preco)
        print(f'\nRestam {disponiveis} bilhetes')
        print( f"Bilhetes:{quantidade_a_comprar}\nValor a pagar:{valor_a_pagar}€")

    def __str__(self):
        return f'\nFilme: {self.nome}\nGenero: {self.genero}\nTempo de Filme: {self.duracao[0]}:{self.duracao[2:]}'
    
class Infantil(Filmes):
    def __init__(self,nome,duracao,produtor):
        super().__init__(nome,duracao,produtor)
        self.genero = "Infantil"

    def informacao(self):
        self.descricao = {'Nome':self.nome,'Genero':self.genero,'Produtora':self.produtor}
        print (f"\nFilme: {self.descricao['Nome']}\nGenero: {self.descricao['Genero']}\nProdutora: {self.descricao['Produtora']}\n{self.duracao_seccao()}\nValor do bilhete: {valor_bilhetes(self.descricao['Genero'])}€")
    
    def comprar_bilhete(self):
        disponiveis = 100
        preco = valor_bilhetes(self.genero)
        quantidade_a_comprar =int(input('Quantos bilhetes pretende comprar?'))
        restantes = disponiveis - quantidade_a_comprar
        valor_a_pagar = float(quantidade_a_comprar) *float(preco)
        print(f'\nRestam {restantes} bilhetes')
        print(f"Bilhetes:{quantidade_a_comprar}\nValor a pagar:{valor_a_pagar}€")
    
    def __str__(self):
        return f'\nFilme: {self.nome}\nGenero: {self.genero}\nTempo de Filme: {self.duracao[0]}:{self.duracao[2:]}'

def valor_bilhetes(Genero):
        valor_bilhetes = {'Accao': 5,'Aventura':5,'Si-Fi':5, "Infantil":3.5}
        for genero in valor_bilhetes:
            if genero == Genero:
                return f'{valor_bilhetes[genero]}'
            elif genero != Genero:
                pass
            else: return '\nGenero nao especifico.'

filme1 = Aventura("Lord of the Ring","3:21:00","New Line Cinema")
filme2 = Aventura("Lord of the Ring","3:10:00",'New Line Cinema')
filme3 = Infantil("Lion King","1:29:00","Disney")
filme4 = Si_Fi("Star Wars IV","2:01:00","LucasArts")
filme5 = Accao("Bad Boys","1:59:00","Don Simpson/Jerry Bruckheimer Films")

filme1.informacao()
filme2.informacao()
filme3.informacao()
filme4.informacao()
filme5.informacao()

valor_bilhetes(None)

filme3.comprar_bilhete()
filme5.comprar_bilhete()
# Out:
# Filme: Lord of the Ring
# Genero: Aventura
# Produtora: New Line Cinema
# Fim da seccao as 23:18H
# Valor do bilhete: 5€
#
# Filme: Lord of the Ring
# Genero: Aventura
# Produtora: New Line Cinema
# Fim da seccao as 23:7H
# Valor do bilhete: 5€
#
# Filme: Lion King
# Genero: Infantil
# Produtora: Disney
# Fim da seccao as 21:26H
# Valor do bilhete: 3.5€
#
# Filme: Star Wars IV
# Genero: Si-Fi
# Produtora: LucasArts
# Fim da seccao as 21:58H
# Valor do bilhete: 5€
#
# Filme: Bad Boys
# Genero: Accao
# Produtora: Don Simpson/Jerry Bruckheimer Films
# Fim da seccao as 21:56H
# Valor do bilhete: 5€
#
# Restam 98 bilhetes
# Bilhetes:2
# Valor a pagar:7.0€
# Restam 97 bilhetes
# Bilhetes:3
# Valor a pagar:15.0€
