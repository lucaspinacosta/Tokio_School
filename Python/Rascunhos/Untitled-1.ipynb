# %%
class Filme:
    def __init__(self, titulo, durancao, lancamento):
        self.titulo=titulo
        self.duracao = durancao
        self.lancamento = lancamento
        print("Criacao do filme:",titulo)

    def __str__(self):
        return "{} ({})".format(self.titulo,self.lancamento)

class Catalogo:
    filmes = []
    def __init__(self,filmes = []):
        self.filmes=filmes
        print ("Criacao de um catalogo")

    def agregar(self,p):
        self.filmes.append(p)
        print("Filmes {}, foi adicionado a lista".format(p.titulo))

    def mostrar(self):
        for p in self.filmes:
            print(p)

d = Filme("O Padrinho",175,1972)
c = Catalogo([d])
print("\n")

c.mostrar()
c.agregar(Filme("O Padrinho: part 2",202,1974))
print("\n")

c.mostrar()
print("\n")

c2 = Catalogo()
c2.mostrar()
print("\n")

pM1 = Filme("Matrix", 175,1999)
pM2 = Filme("Matrix Reloaded",175,2003)
pM3 = Filme("Matrix Revolution",175,2003)
print("\n")

c3 = Catalogo([pM1,pM2,pM3])
c3.mostrar()
# Out:
# Criacao do filme: O Padrinho
# Criacao de um catalogo
#
#
# O Padrinho (1972)
# Criacao do filme: O Padrinho: part 2
# Filmes O Padrinho: part 2, foi adicionado a lista
#
#
# O Padrinho (1972)
# O Padrinho: part 2 (1974)
#
#
# Criacao de um catalogo
#
#
# Criacao do filme: Matrix
# Criacao do filme: Matrix Reloaded
# Criacao do filme: Matrix Revolution
#
#
# Criacao de um catalogo
# Matrix (1999)
# Matrix Reloaded (2003)
# Matrix Revolution (2003)

# %%
class Utilizador:
    def __init__(self, user_name,primeiro_nome,ultimo_nome, password):
        self.user_name = user_name
        self.primeiro_nome = primeiro_nome
        self.ultimo_nome = ultimo_nome
        self.password = password

    def __str__(self):
        return "{}".format(self.user_name)


class Dados_Users:
    utilizadores = []

    def __init__(self,utilizadores = []):
        self.utilizadores=utilizadores
        print ("Lista de utilizadores")

    def inserir(self,x):
            if x not in self.utilizadores:
                self.utilizadores.append(x)
                #print("Utilizador: {}".format(x.user_name))
            else: print("{} em utilizacao.\nPor favor escolha outro username.".format(x.user_name))
        

    def mostrar(self):
        for x in self.utilizadores: print(x)



d = Dados_Users()
x = Utilizador("pao_deQueijo", "Lucas","Costa",123456)
d.inserir(x)
d.inserir(Utilizador("Pseidon",'Joao', 'Pires', 12345))
d.inserir(Utilizador("gato_loco",'Lucas','Pina',12345))



d.mostrar()
# Out:
# Lista de utilizadores
# pao_deQueijo
# Pseidon
# gato_loco

# %%
class Exemplo:
    __atributo_privado = "Atributo privado"

    def __metodo_privado(self):
        print ("nao pode ser chamado fora da funcao")

    def metodo_publico(self):
        return self.__metodo_privado()
    
    #Getter
    @property
    def atributo_privado(self):
        print("Getter")
        return self.__atributo_privado

    #Setter
    @atributo_privado.setter
    def atributo_privado(self, novoValor):
        print("Setter")
        self.__atributo_privado=novoValor

e = Exemplo()

print(e.atributo_privado)
e.atributo_privado= "ola mundo"
print(e.atributo_privado)
e.metodo_publico()
# Out:
# Getter
# Atributo privado
# Setter
# Getter
# ola mundo
# nao pode ser chamado fora da funcao

# %%
class Exemplo2:
    __atributo_privado = "Atributo privado"
    
    def __metodo_privado(self):
        print ("metodo privado")

    def metodo_publico(self):
        return self.__metodo_privado()

    #Getter
    @property
    def ver_valor(self):
        print("Getter")
        return self.__atributo_privado

    #Setter
    @ver_valor.setter
    def ver_valor(self,novoValor):
        print("Setter")
        self.__atributo_privado = novoValor

e = Exemplo2()

print(e.ver_valor)
# Out:
# Getter
# Atributo privado

# %%
class Pessoa:
    __nome = "Nome privado"
    def __init__(self,nome):
        self.__nome=nome

    @property
    def nome(self):
        return self.__nome

    @nome.setter
    def nome(self,novoNome):
        print("Setter")
        self.__nome= novoNome

p1= Pessoa('l')

print(p1.nome)
# Out:
# l

# %%
class Alunos:
    def __init__(self,nome, nota1):
        self.nome = nome
        self.nota1= nota1
        """self.nota2 = nota2
        self.nota3 = nota3
        self.media = (nota1+nota2+nota3)/3"""
        print("Aluno {}, criado com sucesso.".format(nome))

    def aval(self):
        if self.nota1 >= 5:
            return "Aprovado"
        else: return "Reprovado"

    def __str__(self):
        return "Aluno: {} || Media: {} || Avaliacao: {}".format(self.nome,int(self.nota1),self.aval())

class Avaliacao() :
    list_Alunos = []

    def __init__(self,list_Alunos = []):
        self.list_Alunos = list_Alunos

    def inserir(self, p):
        self.list_Alunos.append(p)
        print ("Aluno {}, adicionado a lista de avaliacao".format(p.nome))
        
    def mostrar_avaliacoes(self):
        for p in self.list_Alunos:
            print(p)
   
a1 = Alunos('Pedro',4)
a2 = Alunos('Joao',3)
a3 = Alunos('Joana',9)

c3 = Avaliacao([a1,a2,a3])
c3.inserir(Alunos("Francisco",4))
c3.mostrar_avaliacoes()
# Out:
# Aluno Pedro, criado com sucesso.
# Aluno Joao, criado com sucesso.
# Aluno Joana, criado com sucesso.
# Aluno Francisco, criado com sucesso.
# Aluno Francisco, adicionado a lista de avaliacao
# Aluno: Pedro || Media: 4 || Avaliacao: Reprovado
# Aluno: Joao || Media: 3 || Avaliacao: Reprovado
# Aluno: Joana || Media: 9 || Avaliacao: Aprovado
# Aluno: Francisco || Media: 4 || Avaliacao: Reprovado

# %%
import math
# Fazer o exercício aqui

class Ponto:
    cordenadas = []
    def __init__(self,cordenadas = []):
        self.cordenadas = cordenadas

        if self.cordenadas[0] == "":
            self.cordenadas[0]= 0
        else: pass

        if self.cordenadas[1] == "":
            self.cordenadas[1] = 0
        else: pass
    
    def __str__(self):
        return '({},{})'.format(self.cordenadas[0],self.cordenadas[1])

    def quadrante(self):
        self.cordenadas[0] = int(self.cordenadas[0])
        self.cordenadas[1] = int(self.cordenadas[1])
        if self.cordenadas[0] == 0 and self.cordenadas[1] == 0:
            return "origem"
        elif self.cordenadas[0] > 0 and self.cordenadas[1] >= 0:
            return "Quadrante I"
        elif self.cordenadas[0] > 0 and self.cordenadas[1] <= 0 :
            return "Quadrante II"
        elif self.cordenadas[0] < 0 and self.cordenadas[1] <= 0:
            return "Quadrante III"
        elif self.cordenadas[0] < 0  and self.cordenadas[1] >= 0:
            return "Quadrante IV"
    
def vetor(x1,x2,y1,y2):
    a = x2 - x1
    b = y2 - y1
    c = math.sqrt(math.pow(a, 2) + math.pow(b, 2))
    return c

x,y =[i for i in input('Introduza X e Y separados por uma virgula:').split(",")]
A = Ponto([2 ,3])
B = Ponto ([5 ,5])
C = Ponto([-3, -1])
D = Ponto([0 ,0])
E = Ponto([x,y])


print(A, A.quadrante())
print(B, B.quadrante())
print(C, C.quadrante())
print(D, D.quadrante())
print(E, E.quadrante())

distancia = vetor(A.cordenadas[0],B.cordenadas[0],A.cordenadas[1],B.cordenadas[1])
print()
print("Distância entre os dois pontos: %0.2f" % distancia);
# Out:
# (2,3) Quadrante I
# (5,5) Quadrante I
# (-3,-1) Quadrante III
# (0,0) origem
# (0,0) origem
#
# Distância entre os dois pontos: 3.61

# %%
# função principal do programa
def main():
  # vamos ler os dados do primeiro vetor
  x1 = float(input("Informe o x do primeiro vetor: "))
  y1 = float(input("Informe o y do primeiro vetor: "))
    
  # vamos ler os dados do segundo vetor
  x2 = float(input("Informe o x do segundo vetor: "))
  y2 = float(input("Informe o y do segundo vetor: "))
        
  # vamos calcular o produto escalar
  pEscalar = (x1 * x2) + (y1 * y2)
    
  # mostramos o resultado
  print("O produto escalar é: %f" % pEscalar)
  
if __name__== "__main__":
  main()
# Out:
# O produto escalar é: 39.000000

# %%
import math

# função que permite calcular a distância
# entre dois pontos no plano (R2)
def distancia2d(x1, y1, x2, y2):
  a = x2 - x1
  b = y2 - y1
  c = math.sqrt(math.pow(a, 2) + math.pow(b, 2))
  return c

# função principal do programa
def main():
  # vamos ler os dados do primeiro ponto
  x1 = 2
  y1 = 3
    
  # vamos ler os dados do segundo ponto
  x2 = 5
  y2 = 5
    
  # vamos obter a distância entre eles
  distancia = distancia2d(x1, y1, x2, y2)
  print("Distância entre os dois pontos: %0.2f" % distancia);
  
if __name__== "__main__":
  main()
# Out:
# Distância entre os dois pontos: 3.61

# %%
import math
from cmath import sqrt

# Fazer o exercício aqui

class Ponto:
    cordenadas = []
    def __init__(self,cordenadas = []):
        self.cordenadas = cordenadas

        if self.cordenadas[0] == "":
            self.cordenadas[0]= 0
        else: pass

        if self.cordenadas[1] == "":
            self.cordenadas[1] = 0
        else: pass

        self.cordenadas[0] = int(self.cordenadas[0])
        self.cordenadas[1] = int(self.cordenadas[1])

    def __str__(self):
        return '({},{})'.format(self.cordenadas[0],self.cordenadas[1])    

    def quadrante(self):

        if self.cordenadas[0] == 0 and self.cordenadas[1] == 0:
            return "origem"
        elif self.cordenadas[0] > 0 and self.cordenadas[1] >= 0:
            return "Quadrante I"
        elif self.cordenadas[0] > 0 and self.cordenadas[1] <= 0 :
            return "Quadrante II"
        elif self.cordenadas[0] < 0 and self.cordenadas[1] <= 0:
            return "Quadrante III"
        elif self.cordenadas[0] < 0  and self.cordenadas[1] >= 0:
            return "Quadrante IV"   

    

    def vetor(self,x2,y2):
        a = sqrt(x2 - self.cordenadas[0])
        b = sqrt(y2 - self.cordenadas[1])
        c = "{:.02f}, {:.02f}".format(sqrt(a),sqrt(b))
        return c

    def distancia(self,x2,y2):
        distancia = math.sqrt(pow(x2-self.cordenadas[0],2) + pow(y2-self.cordenadas[1],2))
        return "{:.02f}".format(distancia)


class Retangulo(Ponto):
    ret_cordenada=[]
    ret2_cordenada=[]
    
    def __init__(self, ret2_cordenada=[],ret_cordenada=[]):
        self.ret_cordenada = ret_cordenada
        self.ret2_cordenada = ret2_cordenada
    
    def inserir_pontos(self,x,y):
        x = self.ret_cordenada
        y = self.ret2_cordenada
        for i in x:
            if i <0:
                i -= i*2
                
        for i in y:
            if i < 0:
                i -= i*2
        
        
        base = x[0]+y[0]
        altura = x[1]+y[1]
        area_retangulo = base * altura
        return "{}.{}.{}".format(base,altura,area_retangulo)

    def mostrar_base(self):
        base = self.ret2_cordenada[0]+self.ret_cordenada[0]
    def __str__(self):
        return "{} || {}".format(self.ret_cordenada,self.ret2_cordenada)


ret1_pt1 = Ponto([-13,10])
ret1_pt2 = Ponto([13,-10])
ret1_pt2plus = Ponto([13,10])

retangulo1 = Retangulo(ret1_pt1,ret1_pt2)

base = ret1_pt1.distancia(ret1_pt2.cordenadas[0],ret1_pt2.cordenadas[1])

altura = retangulo1.inserir_pontos(ret1_pt1,ret1_pt2)

print(base)
print(altura)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\lucas\Documents\Ineteresting GITS\Tokio_School\Python\Rascunhos\Untitled-1.ipynb Cell 10' in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/Ineteresting%20GITS/Tokio_School/Python/Rascunhos/Untitled-1.ipynb#ch0000009?line=85'>86</a> retangulo1 = Retangulo(ret1_pt1,ret1_pt2)
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/Ineteresting%20GITS/Tokio_School/Python/Rascunhos/Untitled-1.ipynb#ch0000009?line=87'>88</a> base = ret1_pt1.distancia(ret1_pt2.cordenadas[0],ret1_pt2.cordenadas[1])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/Ineteresting%20GITS/Tokio_School/Python/Rascunhos/Untitled-1.ipynb#ch0000009?line=89'>90</a> altura = retangulo1.inserir_pontos(ret1_pt1,ret1_pt2)
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/Ineteresting%20GITS/Tokio_School/Python/Rascunhos/Untitled-1.ipynb#ch0000009?line=91'>92</a> print(base)
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/Ineteresting%20GITS/Tokio_School/Python/Rascunhos/Untitled-1.ipynb#ch0000009?line=92'>93</a> print(altura)
#
# c:\Users\lucas\Documents\Ineteresting GITS\Tokio_School\Python\Rascunhos\Untitled-1.ipynb Cell 10' in Retangulo.inserir_pontos(self, x, y)
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/Ineteresting%20GITS/Tokio_School/Python/Rascunhos/Untitled-1.ipynb#ch0000009?line=59'>60</a> x = self.ret_cordenada
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/Ineteresting%20GITS/Tokio_School/Python/Rascunhos/Untitled-1.ipynb#ch0000009?line=60'>61</a> y = self.ret2_cordenada
# ---> <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/Ineteresting%20GITS/Tokio_School/Python/Rascunhos/Untitled-1.ipynb#ch0000009?line=61'>62</a> for i in x:
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/Ineteresting%20GITS/Tokio_School/Python/Rascunhos/Untitled-1.ipynb#ch0000009?line=62'>63</a>     if i <0:
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/Ineteresting%20GITS/Tokio_School/Python/Rascunhos/Untitled-1.ipynb#ch0000009?line=63'>64</a>         i -= i*2
#
# TypeError: 'Ponto' object is not iterable

# %%
x = self.ret
if x <0:
    x -= x*2
    print(x)
# Out:
# 13
